# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.metrics import make_scorer, accuracy_score
import json
import scipy.stats 
import pickle
import sklearn.model_selection
import sklearn.ensemble
import itertools
from multiprocessing import Pool
import time

# %%
#load files
results = pd.read_csv('../data/results/model_results.csv', index_col=0)

# %%
#build a random forest model to predict slow/fast codon labels based on position, structure (pLDDT), and amino acid
#this can be used as a comparison for how much of the model's gain in accuracy can be explained just by position and structure
aa_enc = sklearn.preprocessing.OneHotEncoder(sparse=False)
idx = ~results.pLDDT.isna()
aa_enc.fit(np.array(results.AA[idx]).reshape(-1, 1))
aa_onehot = aa_enc.transform(np.array(results.AA[idx]).reshape(-1, 1))
X = np.concatenate((aa_onehot, np.array(results[['pLDDT', 'position']].loc[idx])), axis=1)
y = np.array(results[['label']].loc[idx]).flatten()
weights = np.array(results['weight'][idx])

# %%
#implement grid search
def crossvalidate(clf, X, y, weights, folds=None, k=5, return_auc = False): #too include weights
    if folds is None:
        folds = np.random.random_integers(k, size=y.shape)
    else:
        assert(k == max(folds))
    scores = []
    auc_scores = []
    for i in range(1,k+1):
        test_idx = folds == i
        clf.fit(X[~test_idx], y[~test_idx], sample_weight=weights[~test_idx])
        scores.append(clf.score(X[test_idx], y[test_idx], sample_weight=weights[test_idx]))
        X_pred = clf.predict_proba(X[test_idx])[:,1]
        auc_scores.append(sklearn.metrics.roc_auc_score(y[test_idx], X_pred,sample_weight=weights[test_idx]))
    if return_auc:
        return scores, auc_scores
    else:
        return scores
    
def crossvalidate_worker(params):
    start_time = time.time()
    print('Start running ', str(params[0]))
    scores = crossvalidate(*params)
    print('Mean accuracy for', str(params[0]), 'is', np.mean(scores), '. Run finished after ', (time.time()-start_time)//60, 'minutes')
    return scores


def gridsearch(X, y, weights, folds, param_grid):
    keys = param_grid.keys()
    values = param_grid.values()
    param_combinations = [dict(zip(keys, combo)) for combo in list(itertools.product(*values))]
    clf_list = [sklearn.ensemble.RandomForestClassifier(**params) for params in param_combinations]
    with Pool(10) as pool:
        scores_list = pool.map(crossvalidate_worker, zip(clf_list, itertools.repeat(X), itertools.repeat(y), itertools.repeat(weights), itertools.repeat(folds)))
    mean_scores = [np.mean(scores) for scores in scores_list]
    print('\n\nBest score is', max(mean_scores), 'for params', param_combinations[mean_scores.index(max(mean_scores))])
    return {'clf_list':clf_list, 'scores_list':scores_list, 'param_combinations':param_combinations}

# %%
param_grid =  {'n_estimators': [20,100,500],
    'max_depth': [5, 10, 20],
    'min_samples_split': [50, 500, 5000],
    'bootstrap': [False]}

np.random.seed(12)
folds = np.random.random_integers(5, size=y.shape)
grid_scores = gridsearch(X, y, weights, folds, param_grid)
# Out:
# /mnt/lareaulab/shelen/anaconda3/envs/gen_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: This function is deprecated. Please call randint(1, 5 + 1) instead
#   import sys
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=50,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=500,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=5000,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=50,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=500,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=5000,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=50,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=500,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=5000,
#                        n_estimators=20)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=50)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=50,
#                        n_estimators=20) is 0.5172008480182181 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=500,
#                        n_estimators=20) is 0.5172552358606388 . Run finished after  1.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=5000,
#                        n_estimators=20) is 0.517145221202266 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=5000)
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=50)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=5000,
#                        n_estimators=20) is 0.5176349863620391 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=50,
#                        n_estimators=20) is 0.516914738721716 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=5000)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=500,
#                        n_estimators=20) is 0.5169720522981164 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=50)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=5000,
#                        n_estimators=20) is 0.5153719011021829 . Run finished after  2.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=50,
#                        n_estimators=20) is 0.5104812711610778 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=5000)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=500,
#                        n_estimators=20) is 0.512504347296297 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=50,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=50) is 0.5172371077916762 . Run finished after  5.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=500,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=500) is 0.5170185298949471 . Run finished after  5.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=5000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=5000) is 0.5169847641357241 . Run finished after  5.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=50,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=50) is 0.5171217056396802 . Run finished after  9.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=500,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=5000) is 0.5179313309687779 . Run finished after  9.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=5000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=500) is 0.5173198490631895 . Run finished after  11.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=50,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=5000) is 0.5156973293577496 . Run finished after  14.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=500,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=50) is 0.5111004965465554 . Run finished after  16.0 minutes
# Start running  RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=5000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=500) is 0.5137950541067806 . Run finished after  16.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=50,
#                        n_estimators=500) is 0.5171914116624384 . Run finished after  25.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=500,
#                        n_estimators=500) is 0.5173953372938611 . Run finished after  26.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=5000,
#                        n_estimators=500) is 0.5171890517014793 . Run finished after  26.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=50,
#                        n_estimators=500) is 0.5172207391997942 . Run finished after  38.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=5000,
#                        n_estimators=500) is 0.5179321285417593 . Run finished after  36.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_split=500,
#                        n_estimators=500) is 0.5173640188239071 . Run finished after  41.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=5000,
#                        n_estimators=500) is 0.5160011939085518 . Run finished after  46.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=500,
#                        n_estimators=500) is 0.5135137864786812 . Run finished after  57.0 minutes
# Mean accuracy for RandomForestClassifier(bootstrap=False, max_depth=20, min_samples_split=50,
#                        n_estimators=500) is 0.510616152240185 . Run finished after  70.0 minutes
#
#
# Best score is 0.5179321285417593 for params {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 5000, 'bootstrap': False}

# %%
param_grid_bootstrap =  {'n_estimators': [20,100,500],
    'max_depth': [5, 10, 20],
    'min_samples_split': [10, 100, 1000],
    'bootstrap': [True],
    'max_samples' : [1000, 10000, 100000],
}
grid_scores_bootstrap = gridsearch(X, y, weights, folds, param_grid_bootstrap)
# Out:
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=10,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=100,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=1000,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=10,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=100,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=1000,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=10,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=100,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=1000,
#                        n_estimators=20)
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=1000,
#                        n_estimators=20) is 0.5005976569100825 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=1000,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=10,
#                        n_estimators=20) is 0.5064767986346222 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=10,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=100,
#                        n_estimators=20) is 0.5077857070448106 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=100,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=1000,
#                        n_estimators=20) is 0.5005976569100825 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=1000,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=1000,
#                        n_estimators=20) is 0.5005976569100825 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=1000,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=100,
#                        n_estimators=20) is 0.507026358782869 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=100,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=10,
#                        n_estimators=20) is 0.5048811778789707 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=10,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=100,
#                        n_estimators=20) is 0.5079669727821912 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=100,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=10,
#                        n_estimators=20) is 0.5050641752576002 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=10,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=1000,
#                        n_estimators=20) is 0.5147288853138032 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=1000,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=10,
#                        n_estimators=20) is 0.514335370588935 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=10,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=100,
#                        n_estimators=20) is 0.514264303386587 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=100,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=1000,
#                        n_estimators=20) is 0.5142288884673205 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=1000,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=1000,
#                        n_estimators=20) is 0.5136899932902347 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=1000,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=100,
#                        n_estimators=20) is 0.5113559128053506 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=100,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=10,
#                        n_estimators=20) is 0.5088186774547347 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=10,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=100,
#                        n_estimators=20) is 0.5087866511240664 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=100,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=10,
#                        n_estimators=20) is 0.5046033574704778 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=10,
#                        n_estimators=20)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=1000,
#                        n_estimators=20) is 0.5168914984180143 . Run finished after  0.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=10,
#                        n_estimators=20) is 0.5167920014871359 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=100)
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=100,
#                        n_estimators=20) is 0.5170963701311948 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=10) is 0.5116022221885469 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=1000,
#                        n_estimators=20) is 0.5169807188402981 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=100,
#                        n_estimators=20) is 0.5154856850539166 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=10,
#                        n_estimators=20) is 0.5146131435649453 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=1000,
#                        n_estimators=20) is 0.5151297224974236 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=100,
#                        n_estimators=20) is 0.5108302915249404 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=10,
#                        n_estimators=20) is 0.5067025105269035 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=1000) is 0.4994023430899176 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=100) is 0.5128078240049712 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=10) is 0.506732355753727 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=1000) is 0.4994023430899176 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=10) is 0.5164480677087289 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=100) is 0.5129161039016211 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=1000) is 0.4994023430899176 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=100) is 0.5118914386607589 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=10) is 0.5041906563781164 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=1000) is 0.5166068150703195 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=100) is 0.5167836571851048 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=1000) is 0.516765525719608 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=10) is 0.5131300153860365 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=100) is 0.5154528491268499 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=1000) is 0.517393629938565 . Run finished after  0.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=1000)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=100) is 0.5132408583274785 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=100)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=10) is 0.5068307423397714 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=10)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=10) is 0.5167619987167954 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=1000) is 0.5170874018892591 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=100) is 0.5172737909528432 . Run finished after  1.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=1000) is 0.5174842115050938 . Run finished after  2.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=10,
#                        n_estimators=500) is 0.5131315128375996 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=10) is 0.5171600023243931 . Run finished after  2.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=100) is 0.5172186140619331 . Run finished after  2.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=1000) is 0.5161181940848251 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=100) is 0.5140185733494032 . Run finished after  2.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=10) is 0.5078056053617825 . Run finished after  3.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=100,
#                        n_estimators=500) is 0.5148003935769099 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=1000, min_samples_split=1000,
#                        n_estimators=500) is 0.4994023430899176 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=10,
#                        n_estimators=500) is 0.5067717108540057 . Run finished after  4.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=1000,
#                        n_estimators=500) is 0.4994023430899176 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=1000, min_samples_split=100,
#                        n_estimators=500) is 0.514466642452881 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=10,
#                        n_estimators=500) is 0.5167155979425522 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=1000,
#                        n_estimators=500) is 0.4994023430899176 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=10,
#                        n_estimators=500) is 0.5042687408197135 . Run finished after  4.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=1000, min_samples_split=100,
#                        n_estimators=500) is 0.5142853474473086 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=100,
#                        n_estimators=500) is 0.516917036047116 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=10000, min_samples_split=1000,
#                        n_estimators=500) is 0.5164713976192606 . Run finished after  3.0 minutes
# Start running  RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=10,
#                        n_estimators=500) is 0.5145342483842927 . Run finished after  4.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=1000,
#                        n_estimators=500) is 0.5171185318376321 . Run finished after  4.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=10000, min_samples_split=100,
#                        n_estimators=500) is 0.5168460348270826 . Run finished after  4.0 minutes
# Start running  RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=1000,
#                        n_estimators=500) is 0.5171120676107204 . Run finished after  4.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=1000,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=100,
#                        n_estimators=500) is 0.5152368510272087 . Run finished after  5.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=100,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=10000, min_samples_split=10,
#                        n_estimators=500) is 0.506115784701138 . Run finished after  5.0 minutes
# Start running  RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=10,
#                        n_estimators=500)
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=10,
#                        n_estimators=500) is 0.5169834013854672 . Run finished after  7.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=1000,
#                        n_estimators=500) is 0.5173078678658287 . Run finished after  6.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=5, max_samples=100000, min_samples_split=100,
#                        n_estimators=500) is 0.5172803512056461 . Run finished after  6.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=10,
#                        n_estimators=500) is 0.5172441842222486 . Run finished after  8.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=1000,
#                        n_estimators=500) is 0.517870576485109 . Run finished after  8.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=10, max_samples=100000, min_samples_split=100,
#                        n_estimators=500) is 0.5176968832932844 . Run finished after  8.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=1000,
#                        n_estimators=500) is 0.5168421918812328 . Run finished after  10.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=100,
#                        n_estimators=500) is 0.5138654389239427 . Run finished after  12.0 minutes
# Mean accuracy for RandomForestClassifier(max_depth=20, max_samples=100000, min_samples_split=10,
#                        n_estimators=500) is 0.509267490945206 . Run finished after  12.0 minutes
#
#
# Best score is 0.517870576485109 for params {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 1000, 'bootstrap': True, 'max_samples': 100000}

# %%
#so, best score is 0.5179321285417593 for params {'n_estimators': 500, 'max_depth': 10, 'min_samples_split': 5000, 'bootstrap': False}
